# %% [markdown]
# ## Navie Bayes in KDB+

# %%
/ Example words
positive : "I am happy because I am learning NLP I am happy not sad"
negative : "I am sad I am learning NLP I am sad not happy"

/Convert the words to symbol list

pos_lis: `$(" " vs positive)
neg_lis: `$(" " vs negative)

show pos_lis
show neg_lis
# Out:
# `I`am`happy`because`I`am`learning`NLP`I`am`happy`not`sad
# `I`am`sad`I`am`learning`NLP`I`am`sad`not`happy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
/postive list
w:()!()
{$[(x in (key w));w[x]+:1;w[x]:1]}'[pos_lis]
# Out:
# 1 1 1 1 2 2 1 1 3 3 2 1 1

# %%
/negative list
v:()!()
{$[(x in (key v));v[x]+:1;v[x]:1]}'[neg_lis]
# Out:
# 1 1 1 2 2 1 1 3 3 2 1 1

# %%
pos_t:1!([] word:(key w);pos: (value w))

# %%
pos_t
# Out:
# word    | pos
# --------| ---
# I       | 3
# am      | 3
# happy   | 2
# because | 1
# learning| 1
# NLP     | 1
# not     | 1
# sad     | 1

# %%
neg_t:1!([] word:(key v); negv: (value v))

# %%
neg_t
# Out:
# word    | negv
# --------| ----
# I       | 3
# am      | 3
# sad     | 2
# learning| 1
# NLP     | 1
# not     | 1
# happy   | 1

# %%
/Join the postive word table and negative word table
word_freq:pos_t lj neg_t
show word_freq
# Out:
# word    | pos negv
# --------| --------
# I       | 3   3
# am      | 3   3
# happy   | 2   1
# because | 1
# learning| 1   1
# NLP     | 1   1
# not     | 1   1
# sad     | 1   2

# %%
/Unkey and Fill null with 0
word_freq: 0!(0^word_freq)
show word_freq
# Out:
# word     pos negv
# -----------------
# I        3   3
# am       3   3
# happy    2   1
# because  1   0
# learning 1   1
# NLP      1   1
# not      1   1
# sad      1   2

# %%
update pos_per:{x % sum word_freq`pos}'[pos], neg_per:{x % sum word_freq`negv}'[negv] from `word_freq
# Out:
# `word_freq

# %%
/Now we can see the frequency percentage of every word 
show word_freq
# Out:
# word     pos negv pos_per    neg_per
# ---------------------------------------
# I        3   3    0.2307692  0.25
# am       3   3    0.2307692  0.25
# happy    2   1    0.1538462  0.08333333
# because  1   0    0.07692308 0
# learning 1   1    0.07692308 0.08333333
# NLP      1   1    0.07692308 0.08333333
# not      1   1    0.07692308 0.08333333
# sad      1   2    0.07692308 0.1666667

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
test:`$" " vs "today I learn"

# %%
test
# Out:
# `today`I`learn

# %%
parse "exec pos_per,negv_per from word_freq where word=`I"
# Out:
# ?
# `word_freq
# ,,(=;`word;,`I)
# ()
# `pos_per`negv_per!`pos_per`negv_per

# %%
l:?[word_freq; enlist(=;`word;enlist `happy);();`pos_per`negv_per!`pos_per`neg_per]

# %%
get_val:{l:?[word_freq; enlist(=;`word;enlist x);();`pos_per`negv_per!`pos_per`neg_per];:(l`pos_per)%(l`negv_per) }

# %%
get_val'[`I`am`happy]
# Out:
# 0.9230769
# 0.9230769
# 1.846154

# %%
{(value x)[0] % (value x)[1]}'[{?[word_freq; enlist(=;`word;enlist x);();`pos_per`negv_per!`pos_per`neg_per]}[`I]]
# Out:
# evaluation error:
#
# type
#
#   [1]  {(value x)[0] % (value x)[1]}
#                         ^
#
#   [0]  {(value x)[0] % (value x)[1]}'[{?[word_freq; enlist(=;`word;enlist x);();`pos_per`negv_per!`pos_per`neg_per]}[`I]]
#                                     ^

# %%
[{?[word_freq; enlist(=;`word;enlist x);();`pos_per`negv_per!`pos_per`neg_per]}[`I]]
# Out:
# pos_per | 0.2307692
# negv_per| 0.25

# %%
[{?[word_freq; enlist(=;`word;enlist x);();`pos_per`negv_per!`pos_per`neg_per]}[`I]]enlist
# Out:
# pos_per | 0.2307692
# negv_per| 0.25
# evaluation error:
#
# type
#
#   [0]  {show x}'[enlist {?[word_freq; enlist(=;`word;enlist x);();`pos_per`negv_per!`pos_per`neg_per]}[`I]]enlist
#                ^

# %%
word_freq
# Out:
# word     pos negv pos_per    neg_per
# ---------------------------------------
# I        3   3    0.2307692  0.25
# am       3   3    0.2307692  0.25
# happy    2   1    0.1538462  0.08333333
# because  1   0    0.07692308 0
# learning 1   1    0.07692308 0.08333333
# NLP      1   1    0.07692308 0.08333333
# not      1   1    0.07692308 0.08333333
# sad      1   2    0.07692308 0.1666667

# %%
select
